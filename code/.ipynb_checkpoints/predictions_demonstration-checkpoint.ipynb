# %% [markdown]
# <a id = "top"></a>
# # Predictions Demonstration
#
# ---
#
# Welcome to the demonstrations notebook! If you find yourself here, first click "Cell" then "Run All". Then click <a href = "#pred">HERE</a> and feel free to start making predictions of your own!
#
# #### Other Notebooks
# - [Cleaning and EDA](cleaning_and_EDA.ipynb)
# - [Modeling](modeling.ipynb)
# - [Additional Modeling](adtl_modeling.ipynb)
# - [Presentation Prep](presentation_prep.ipynb)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %matplotlib inline

# %%
ames = pd.read_csv("../datasets/ames_plus.csv")

# %%
features = ["total_sq_ft", "age", "kitchen_qual", "bsmt_qual", "garage_cars"]

# %%
X = ames[features]
y = ames["saleprice"]

mlr_model = LinearRegression()
mlr_model = mlr_model.fit(X, y)

intercept = mlr_model.intercept_

mlr_model.score(X, y)
# Out:
# 0.8106088549905086

# %%
cross_val_score(mlr_model, X, y, cv = 5).mean()
# Out:
# 0.8095004582225671

# %%
coefs = pd.DataFrame()
coefs["feature"] = features
coefs["mlr_coefs"] = mlr_model.coef_
coefs
# Out:
#         feature     mlr_coefs
# 0   total_sq_ft     56.675486
# 1           age   -282.355827
# 2  kitchen_qual  30395.625164
# 3     bsmt_qual   4995.360010
# 4   garage_cars  13276.081937

# %%
def make_prediction(sq_ft, age, kit, bsmt, cars, name = "your_dream_home.png", save = False):
    df = pd.DataFrame({
        "total_sq_ft": [sq_ft],
        "age": [age],
        "kitchen_qual": [kit],
        "bsmt_qual": [bsmt],
        "garage_cars": [cars]
    })
    
    # Code adapted from data viz lecture
    plt.figure(figsize=(8, 6))

    plt.text(x = 0.5,                       
             y = 0.99,                  
             s = f"With {sq_ft} square feet...",
             ha = 'center',                     
             va = 'center',                    
             size = 30,                      
             alpha = 0.6)                     

    plt.text(x = 0.5,
             y = 0.86,                          
             s = f"{age} years old...",
             ha = 'center',
             va = 'center',       
             size = 30,                         
             alpha = 0.6)                      

    plt.text(x = 0.5,                          
             y = 0.73,                         
             s = f"A kitchen quality of {kit}...",
             ha = 'center',            
             va = 'center',                 
             size = 30,                            
             alpha = 0.6)               

    plt.text(x = 0.5,                         
             y = 0.60,                          
             s = f"A basement quality of {bsmt}...",
             ha = 'center',                    
             va = 'center',                
             size = 30,                     
             alpha = 0.6)                     

    plt.text(x = 0.5,                         
             y = 0.47,                            
             s = f"And {cars} cars in the garage...",
             ha = 'center',                     
             va = 'center',                
             size = 30,                     
             alpha = 0.6)             

    plt.text(x = 0.5,                       
             y = 0.34,                      
             s = "Your dream home will cost only...",
             ha = 'center',                  
             va = 'center',            
             size = 30,               
             alpha = 0.6)                
    
    plt.text(x = 0.5,
             y = 0.09,
             s = "$" + str(int(mlr_model.predict(df))) + "!",
             ha = 'center',
             va = 'center',
             size = 100,
             alpha = 1)

    plt.axis('off');

    if save:
        plt.savefig("../images/" + str(name))

        
#     print(f"With {sq_ft} square feet...")
#     print(f"{age} years old...")
#     print(f"A kitchen quality of {kit}...")
#     print(f"A basement quality of {bsmt}...")      
#     print(f"And {cars} cars in the garage...")
#     print("Your dream home will cost only", int(mlr_model.predict(df)), "dollars!")
#     return int(mlr_model.predict(df))

# %%
# Finding the price of Jimmy's house!

make_prediction(2000, 5, 3, 3, 2, name = "jimmys_dream_home.png", save = True)

# %%
# Calculating the age of Jimathy's house using his budget of 144,943 dollars!

ph = ((56.67548555 * 5000) + (30395.62516387 * 5) + (4995.36001 * 5) + (13276.08193661 * 5) + intercept - 144943)
ph / 282.35582703
# Out:
# 998.9134230758852

# %%
# Calculating the price of Jimathy's house assuming he wants a new house.

make_prediction(5000, 0, 5, 5, 5)

# %% [markdown]
# <a id = "pred"></a>
#
# ### Choose your own features here!

# %%
# Change these values to your liking, then press Shift and Enter to run!

dream_home = {
    
    "SquareFootage": 37,
    
    "Age": 10,
    
    "KitchenQuality": 1, 
    
    "BasementQuality": 5,
    
    "GarageCars": 4
    
    }

make_prediction(dream_home["SquareFootage"], 
                dream_home["Age"], 
                dream_home["KitchenQuality"], 
                dream_home["BasementQuality"], 
                dream_home["GarageCars"],
                name = "presentation_house.png",
                save = True)

# %% [markdown]
# ---
# - [Back to top](#top)
